# %%
import urllib.request as req # 同網路連線
url = "https://www.basketball-reference.com/contracts/players.html"

# 使自己看起來像是個人類使用者 so we ahve to do : 建立一個 Request 物件, 附加 Request Headers的資訊
request = req.Request(url, headers={
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"
})
with req.urlopen(request) as response: # (url) 轉-> (request) 
    data = response.read().decode("utf-8")

print(data)
# Out:
# <!DOCTYPE html>
# <html data-version="klecko-" data-root="/home/bbr/build" itemscope itemtype="https://schema.org/WebSite" lang="en" class="no-js" >
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />
#     <link rel="dns-prefetch" href="https://d2p3bygnnzw9w3.cloudfront.net/req/202007313" />
#
#     <title>2019-20 NBA Player Contracts
#  | Basketball-Reference.com</title>
#
#
#     <meta name="Description" content="Summary of current NBA player contracts">
#     <link rel="canonical" href="https://www.basketball-reference.com/contracts/players.html" />
#
# <!-- include:start ="/inc/klecko_header_bbr.html_f" -->
# <!-- no:cookie fast load the css.           -->
# ...

# %%
root = bs4.BeautifulSoup(data, "html.parser")
print(root)
#print("標題名稱 : ",root.title.string)
titles_all = root.find_all("thead")
#titles = titles_all.find_all("/th")
print(titles_all)
#print(titles)


#     # 4.用for迴圈抓出所有值
# for i in titles_all :  
#     if i.th != None: # 因為有些<>標籤中是沒有a.的, 因此設一個條件句 : 印出<>標籤有a的值  (if i.a(迴圈a) !=(不等於空))
#          print(i.th.string)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" data-root="/home/bbr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202007313" rel="dns-prefetch"/>
# <title>2019-20 NBA Player Contracts
#  | Basketball-Reference.com</title>
# <meta content="Summary of current NBA player contracts" name="Description"/>
# <link href="https://www.basketball-reference.com/contracts/players.html" rel="canonical"/>
# <!-- include:start ="/inc/klecko_header_bbr.html_f" -->
# <!-- no:cookie fast load the css.           -->
# ...

# %%
# 抓取下一頁的連結 : 
nextlink = root.find("a", string ="‹ 上頁") # 找到內文是 < 上頁的 a 標籤
#print(nextlink)
print(nextlink["href"]) # 抓出屬性href(href 是我們要找的資料: )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-48aed0e66613> in <module>
#       2 nextlink = root.find("a", string ="‹ 上頁") # 找到內文是 < 上頁的 a 標籤
#       3 #print(nextlink)
# ----> 4 print(nextlink["href"]) # 抓出屬性href(href 是我們要找的資料: )
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import bs4
import urllib.request as req

def getData(url):  

    request = req.Request(url, headers={
        "cookie":"over18=1",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"
    })
    with req.urlopen(request) as response: # (url) 轉-> (request) 
        data = response.read().decode("utf-8")

    root = bs4.BeautifulSoup(data, "html.parser")
    print("標題名稱 : ",root.title.string)
    #titles_all = root.find_all("div",class_="title")
    titles_all = root.find_all("tr",class_="nba-container-wrapper")

#     for i in titles_all :  
#         if i.a != None: 
#             print(i.a.string)
pageURL = "https://www.basketball-reference.com/contracts/players.html"
getData(pageURL)
# Out:
# 標題名稱 :  2019-20 NBA Player Contracts
#  | Basketball-Reference.com
